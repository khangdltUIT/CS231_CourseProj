# %% [markdown]
# <a href="https://colab.research.google.com/github/khangdltUIT/CS231_CourseProj/blob/main/animeGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cài đặt các thư viện cần thiết

# %%
# !pip install ffmpeg
import imageio
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import clear_output
import io
import base64
import os
import cv2
from google.colab import files
# %matplotlib inline

# %tensorflow_version 1.x
# Out:
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-cp36-none-any.whl size=6083 sha256=6e2945e68aae3fbc0f01cc087a419a6ced15dff3c650afc1c76329027185da55
#   Stored in directory: /root/.cache/pip/wheels/b6/68/c3/a05a35f647ba871e5572b9bbfc0b95fd1c6637a2219f959e7a
# Successfully built ffmpeg
# ...
# TensorFlow 1.x selected.

# %% [markdown]
# # Clone github của tác giả

# %%
# !git clone  https://github.com/TachibanaYoshino/AnimeGAN.git
# %cd AnimeGAN
# !wget https://github.com/TachibanaYoshino/AnimeGAN/releases/download/vgg16%2F19.npy/vgg19.npy
# !wget https://github.com/TachibanaYoshino/AnimeGAN/releases/download/Haoyao-style_V1.0/Haoyao-style.zip
# !unzip /content/AnimeGAN/Haoyao-style.zip -d pppoint
# !rm /content/AnimeGAN/Haoyao-style.zip
# !cp /content/AnimeGAN/vgg19.npy /content/AnimeGAN/vgg19_weight
# !rm /content/AnimeGAN/vgg19.npy
# Out:
# Cloning into 'AnimeGAN'...
# remote: Enumerating objects: 1199, done.
# remote: Total 1199 (delta 0), reused 0 (delta 0), pack-reused 1199
# Receiving objects: 100% (1199/1199), 266.61 MiB | 47.96 MiB/s, done.
# Resolving deltas: 100% (338/338), done.
# /content/AnimeGAN
# --2020-12-26 00:52:47--  https://github.com/TachibanaYoshino/AnimeGAN/releases/download/vgg16%2F19.npy/vgg19.npy
# Resolving github.com (github.com)... 192.30.255.112
# Connecting to github.com (github.com)|192.30.255.112|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# # Download Ảnh

# %%
# !mkdir img
# %cd 'img'
# !wget https://i.pinimg.com/originals/c2/a2/b7/c2a2b72d1e852146b3d539115c85f0fe.jpg
# %cd ..
# Out:
# /content/AnimeGAN/img
# --2020-12-25 13:52:23--  https://i.pinimg.com/originals/c2/a2/b7/c2a2b72d1e852146b3d539115c85f0fe.jpg
# Resolving i.pinimg.com (i.pinimg.com)... 184.26.81.47, 2600:1409:12:397::1931, 2600:1409:12:3b3::1931, ...
# Connecting to i.pinimg.com (i.pinimg.com)|184.26.81.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 213018 (208K) [image/jpeg]
# Saving to: ‘c2a2b72d1e852146b3d539115c85f0fe.jpg’
#
# c2a2b72d1e852146b3d 100%[===================>] 208.03K  --.-KB/s    in 0.02s
#
# 2020-12-25 13:52:23 (8.57 MB/s) - ‘c2a2b72d1e852146b3d539115c85f0fe.jpg’ saved [213018/213018]
#
# /content/AnimeGAN

# %% [markdown]
# # Ảnh download

# %%
from google.colab.patches import cv2_imshow
import cv2

path = './img'
for r,d,f in os.walk(path):
    for file in f:
        img_pth = path + '/' + file
        img = cv2.imread(img_pth)
        cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x960 at 0x7FF6F8AD2FD0>

# %% [markdown]
# # Chuyển ảnh input sang ảnh theo phong cách anime

# %%
# !python test.py --checkpoint_dir checkpoint/generator_Hayao_weight --test_dir /content/AnimeGAN/img --style_name H
delete_log = True
if delete_log == True: clear_output()

# %% [markdown]
# # Hiển thị ảnh sau khi chuyển

# %%
path = './results/H'
for r,d,f in os.walk(path):
    for file in f:
        img_pth = path + '/' + file
        img = cv2.imread(img_pth)
        cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=960x960 at 0x7FF6F8AD24A8>
